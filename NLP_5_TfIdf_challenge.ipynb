# %% [markdown]
# <a href="https://colab.research.google.com/github/chouat2207/Python/blob/main/NLP_5_TfIdf_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1d7ef192-f971-4ae4-8324-85ace7837461" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d7ef192-f971-4ae4-8324-85ace7837461">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27475  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27476  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27477  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27478  ed167662a5                         But it was worth it  ****.
# 27479  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment
# 0                    I`d have responded, if I were going   neutral
# ...

# %%
df = df[(df['sentiment']=="negative") | (df['sentiment']=="positive")]

# %%
df
# Out:
#            textID                                               text  \
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# 6      6e0c6d75b1  2am feedings for the baby are fun when he is a...
# ...           ...                                                ...
# 27474  b78ec00df5                                     enjoy ur night
# 27475  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27476  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27477  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27478  ed167662a5                         But it was worth it  ****.
#
#                     selected_text sentiment
# 1                        Sooo SAD  negative
# 2                     bullying me  negative
# ...

# %%
df[df['sentiment'].isin(["positive", "negative"])]
# Out:
#            textID                                               text  \
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# 6      6e0c6d75b1  2am feedings for the baby are fun when he is a...
# ...           ...                                                ...
# 27474  b78ec00df5                                     enjoy ur night
# 27475  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27476  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27477  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27478  ed167662a5                         But it was worth it  ****.
#
#                     selected_text sentiment
# 1                        Sooo SAD  negative
# 2                     bullying me  negative
# ...

# %%
(df[df['sentiment']=="negative"].value_counts().sum()/len(df))*100
# Out:
# 47.55240481574283

# %%
(df[df['sentiment']=="positive"].value_counts().sum()/len(df))*100
# Out:
# 52.44759518425717

# %%
from sklearn.model_selection import train_test_split

# %%
X= df['text']
y=df['sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,train_size=0.75, random_state=32)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf  = TfidfVectorizer()

# %%
X_train_cv = tfidf.fit_transform(X_train)
X_train_cv
# Out:
# <12272x15806 sparse matrix of type '<class 'numpy.float64'>'
# 	with 144578 stored elements in Compressed Sparse Row format>

# %%
X_test_cv = tfidf .transform(X_test)
X_test_cv
# Out:
# <4091x15806 sparse matrix of type '<class 'numpy.float64'>'
# 	with 44633 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Entraîner une régression logistique

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression()
model.fit(X_train_cv, y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = model.predict(X_train_cv)
y_test_pred = model.predict(X_test_cv)

# %%
# Scores
train_score = accuracy_score(y_train, y_train_pred)
test_score = accuracy_score(y_test, y_test_pred)

print(f"Score d'entraînement : {train_score:.3f}")
print(f"Score de test : {test_score:.3f}")
# Out:
# Score d'entraînement : 0.931
# Score de test : 0.873
